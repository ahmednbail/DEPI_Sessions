# %%
print('my name is DEPI Round 4')
# Out:
# my name is DEPI Round 4

# %%
x = 50
type(x)
# Out:
# int

# %%
print('Hello world')
print('D4 learning')
# Out:
# Hello world
# D4 learning

# %%
x= 10
y=20
print('value of x:',x,'value of y:',y)
# Out:
# value of x: 10 value of y: 20

# %%
name= 'Ahmed Nabil'
course_name='Microsoft Data Engineering'
id='10'

print(f'my name is {name},I am currently enrolled in {course_name},my course id is {id}')
# Out:
# my name is Ahmed Nabil,I am currently enrolled in Microsoft Data Engineering,my course id is 10

# %%
sent1="depi .learning depi."
split_txt=sent1.split()
print(split_txt)
# Out:
# ['depi', '.learning', 'depi.']

# %%
sent_new=' '.join(split_txt)
print(sent_new)
# Out:
# welcome into our company

# %%
sent1='welcome into our company'
split_txt=sent1.split()
sent2=' '.join(split_txt)
print(sent2)
# Out:
# welcome into our company

# %%
list_one =[1,2,3,4,"amit","learning",True,[1,2,3,"True",["ml","dl","ds"]]]
print(type(list_one))
# Out:
# <class 'list'>

# %%
list_one =[1,2,3,4,"amit","learning",True,[1,2,3,"True",["ml","dl","ds"]]]
print(list_one)
# Out:
# [1, 2, 3, 4, 'amit', 'learning', True, [1, 2, 3, 'True', ['ml', 'dl', 'ds']]]

# %%
list_one[7][4][0]
# Out:
# 'ml'

# %%
#program that make the select and inter what he want to delete from list
input_list=['depi','learning','data engineering']
item =input("enter your value:")
if item in input_list:
    input_list.remove(item)
    print(f'on put list: {input_list}')
else:
    print('item not in list')
# Out:
# on put list: ['depi', 'data engineering']
