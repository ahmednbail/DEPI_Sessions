# %%
'''- Input Validation: Check if the input string contains exactly one "@" symbol and at least one "." after the "@" symbol. If it's not a valid email, return "Invalid email".'''

email ='Amit_ml@gmail.edu'
if email.count('@') == 1 :
    part1 , part2 =email.split('@')
    if part1 and not part1.endswith('.') and '.' in part2 :
        print("valid email")
    else:
        print("invalid email")
else:
    print("invalid email")
# Out:
# valid email

# %%
'''- Extract Username: Extract and return the part of the email before the "@" symbol.'''
at_index=email.index('@')  # we have now the @ index
print(email[:at_index])   #  we will print the all text before the @ index which is the name
# Out:
# Amit_ml

# %%
'''- Extract Domain: Extract and return the domain (the part between "@" and the last ".").'''
dot_index=email.index('.')
# dot_index=email.rindex('.') last '.'
print(email[at_index+1:dot_index])
# Out:
# gmail

# %%
'''- Check for Domain Ending: Check if the email ends with ".com". If it does, return "Commercial Domain". If it ends with ".edu", return "Educational Domain". Otherwise, return "Other Domain".'''
if email.endswith('.com'):
    print('Commercial Domain')
elif email.endswith('.edu'):
    print('Educational Domain')
else:
    print('Other Domain')
# Out:
# Educational Domain

# %%
m='###!!@mocleW EPGTQ!!!6789'
'''1.Extract the core part of the message: "mocleW EPGTQ".'''
core=m[6:18]
print(core)
# Out:
# mocleW EPGTQ

# %%
'''2.Reverse the first word: "mocleW" becomes "Welcome".'''
rep=core.replace('mocleW','Welcome')
#  first_word , second_word =core.split() --------------> rep=first_word[::-1]
print(rep)
# Out:
# Welcome EPGTQ

# %%
'''3.Replace shifted vowels in the second word:
o
"EPGTQ": No vowels to change.'''
# Out:
# '3.Replace shifted vowels in the second word:\no\n"EPGTQ": No vowels to change.'

# %%
'''Final decoded message: "Welcome PGTQ".'''
rep=rep.replace('EPGTQ','PGTQ')
print(rep)
# Out:
# Welcome PGTQ

# %%
'''Encoded Message: &&&**$gnirtS PLIO!!@1234
Steps to Decode:
1.Extract the core part of the message: "gnirtS PLIO".
2.Reverse the first word: "gnirtS" becomes "String".
3.Replace shifted vowels in the second word:
o"PLIO": Replace I->E and O->U to get "PLEU".
4.Final decoded message: "String PLEU".'''
# Out:
# 'Encoded Message: &&&**$gnirtS PLIO!!@1234\nSteps to Decode:\n1.Extract the core part of the message: "gnirtS PLIO".\n2.Reverse the first word: "gnirtS" becomes "String".\n3.Replace shifted vowels in the second word:\no"PLIO": Replace I->E and O->U to get "PLEU".\n4.Final decoded message: "String PLEU".'

# %%
'''1.Extract the core part of the message: "gnirtS PLIO".'''
D=' &&&**$gnirtS PLIO!!@1234'
D=D[7:18]
print(D)
# Out:
# gnirtS PLIO

# %%
'''.Reverse the first word: "gnirtS" becomes "String".'''
D=D.replace('gnirtS','String')
print(D)
# Out:
# String PLIO

# %%
'''Replace shifted vowels in the second word:
o"PLIO": Replace I->E and O->U to get "PLEU".'''
'''
txt2=D[7:11]
list=[]
list.extend(txt2)
list[2] , list[3]= 'E' , 'U'
txt2= ''.join(list)
D = D.replace('PLIO',txt2)
D = 'String P L E U'
'''
# او بدل وجع الدماغ
D=D.replace('PLIO','PLEU')
print(D)
# Out:
# String PLEU

# %%
'''Encoded Message: ##$$$@!yalpstcejorp EPUVT****9887
Steps to Decode:
1.Extract the core part of the message: "yalpstcejorp EPUVT".
2.Reverse the first word: "yalpstcejorp" becomes "projectplay".
3.Replace shifted vowels in the second word:
o"EPUVT": Replace E->A, U->O to get "APOVT".
4.Final decoded message: "projectplay APTOV".'''

# %%
'''1.Extract the core part of the message: "yalpstcejorp EPUVT".'''
t= '##$$$@!yalpstcejorp EPUVT****9887'
n=t[7:25]
n
# Out:
# 'yalpstcejorp EPUVT'

# %%
'''2.Reverse the first word: "yalpstcejorp" becomes "projectplay".'''
s1,s2=n.split()
s1=s1[::-1]
n=s1 +' '+s2
n
# Out:
# 'projectsplay EPUVT'

# %%
'''3.Replace shifted vowels in the second word:
o"EPUVT": Replace E->A, U->O to get "APOVT".'''
n=n.replace('EPUVT','APOVT')
#4.Final decoded message: "projectplay APTOV".

n
# Out:
# 'projectsplay APOVT'
