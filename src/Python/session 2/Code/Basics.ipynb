# %%
x=['ahmed',2,10]
for i in x  :
    print(i)
# Out:
# ahmed
# 2
# 10

# %%
for i in range(6):
    if i ==3:
        break
    print(i)
# Out:
# 0
# 1
# 2

# %%
for i in range(6):
    if i ==3:
        continue
    print(i)
# Out:
# 0
# 1
# 2
# 4
# 5

# %%
for i in range(6):
    if i ==3:
        print('now will continue')
        continue
    print(i)
# Out:
# 0
# 1
# 2
# now will continue
# 4
# 5

# %%
x=6
while x>0:
    print(x)
    x-=1
# Out:
# 6
# 5
# 4
# 3
# 2
# 1

# %%
x=6
while x>0:
    print('python')
    x-=1
# Out:
# python
# python
# python
# python
# python
# python

# %%
try:
    5/0
except:
    print('Not accept divide by zero')
# Out:
# Not accept divide by zero

# %%
try:
    x=10
    y=int(input('Enter a number: '))
    x/y
except Exception as e:
    print(e)

# %%
import os

# %%
base=r'D:\Ahmed\DEPI\DEPI_projects\src\Python\session 2\Code'
os.listdir(base)
# Out:
# ['Basics.ipynb']
