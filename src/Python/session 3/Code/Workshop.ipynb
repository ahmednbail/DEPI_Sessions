# %%
from http.client import responses


def factorial_1(num:int):
    if num ==0 :
        return 1
    if num == 1:
        return 1
    return num*factorial_1(num-1)

# %%
factorial_1(5)

# %%
def is_prime(num:int):
    for i in range(2,num):
        if num%i==0:
            return False
    return True

# %%
is_prime(20)

# %%
def dividors(num1,num2):
    mn=min(num1,num2)
    common_div=[]
    for i in range(1,mn+1):
        if num1%i==0 and num2%i==0:
            common_div.append(i)
    return common_div

# %%
dividors(20,15)

# %%
even=[]
def even_num(num:int):
    for i in range(num):
        if i %2==0:
            even.append(i)
    return even

# %%
even_num(20)

# %%
"hello world"
def revese(txt:str):
    txt=txt[::-1]
    return txt

# %%
s=input("inter your test:")
revese(s)

# %%
def revers_txt(txt:str):
    txt=txt.split()
    new_txt =txt.reverse()
    new_txt=' '.join()
    return new_txt

# %%
revers_txt("hello world")

# %%
import random
char='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ1234567890!@#$%^&*'

password=''
pass_legth=int(input("length of password:"))
for _ in range(pass_legth):
    password+=random.choice(char)
password
# Out:
# 'MJKJ39qY9pYa49z20vm6'

# %%
words = ["Welcome", "Ali", "Hi", "Ali", "No", "Hi", "No", "Ali", "No", "Ali"]
unique_words=set(words)
count={word:words for word in unique_words}
for i in unique_words:
  print(f"word:{i}, count:{words.count(i)}")
# Out:
# word:Ali, count:4
# word:No, count:3
# word:Hi, count:2
# word:Welcome, count:1

# %%
import random

responses={"hello": ["Hello!", "Hi there!", "Greetings!"],
    "how are you": ["I'm doing well, thank you!", "I'm fine, how about you?"],
    "goodbye": ["Goodbye!", "See you later!", "Farewell!"],
    "default": ["I'm sorry, I didn't understand.", "Could you please rephrase that?"]}
print("Chatbot:Hi! How can I help you?")
while True:
    user_input =input("User:").lower()
    response_found = False
    for key in responses:
        if key in user_input:
            print("Chatbot:", random.choice(responses[key]))
            response_found = True
            break
        if not response_found:
            print("Chatbot:", random.choice(responses['default']))
        if user_input =='goodbye':
            break
